# %% [markdown]
# ## Nonlinear Algorithms
# All  Nonlinear  Algorithms  are  non-parametric  and  more flexible. They are not sensible to outliers and do not require
# any shape of distribution.

# %% [markdown]
# ### Classification and Regression Trees
# - Also referred as CART or Decision Trees, this algorithm is the foundation of Random Forest and Boosted Trees.

# %% [markdown]
# #### Representation:
# - The  model  representation  is  a  binary  tree,  where  each node is an input variable x with a split point and each leaf contain an output variable y for prediction

# %% [markdown]
# ![image.png](attachment:84739049-eb72-419e-b6f0-57af30e31188.png)

# %% [markdown]
# - The  model  actually  split  the  input  space  into  (hyper) rectangles, and predictions are made according to the area observations fall into..

# %% [markdown]
# ![image.png](attachment:2bc47d45-8bc4-43c8-ba79-979babd4e403.png)

# %% [markdown]
# ![image.png](attachment:13f2d36f-f403-469c-b2d7-d0e8d0af3812.png)

# %% [markdown]
# ![image.png](attachment:0bdcf454-e274-42af-92a6-1a031895beb9.png)

# %% [markdown]
# ![image.png](attachment:9c96f4df-7fa3-4023-8f14-18adf8bc4188.png)

# %% [markdown]
# ![image.png](attachment:98ab4ec5-bde9-4f27-be76-33795a85fa10.png)

# %%
Note: A decision tree can contain categorical data (YES/NO) as well as numeric data.

# %% [markdown]
# ![image.png](attachment:e39d8fe4-050b-47b2-a751-004f5b137308.png)

# %% [markdown]
# ![image.png](attachment:89456be2-355d-452a-a530-d6eba2587820.png)

# %% [markdown]
# ![image.png](attachment:089c6f34-8d65-4590-9347-6b70b7df763c.png)

# %%
How does the Decision Tree algorithm Work?

# %% [markdown]
# ![image.png](attachment:71c5f988-2984-410d-b874-d32528dcb906.png)

# %% [markdown]
# ![image.png](attachment:907a946a-08d9-4c88-9d85-544ae3d74585.png)

# %% [markdown]
# ![image.png](attachment:0a985a6f-ebdf-4de4-8b05-342d2f3c99e3.png)

# %% [markdown]
# ![image.png](attachment:00539e95-8b0e-481e-b57b-4e3a83fd43c8.png)

# %%
Information Gain= Entropy(S)- [(Weighted Avg) *Entropy(each feature)

# %%
Entropy: Entropy is a metric to measure the impurity in a given attribute. It specifies randomness in data. Entropy can be calculated as:

Entropy(s)= -P(yes)log2 P(yes)- P(no) log2 P(no)
Where,

    S= Total number of samples
    P(yes)= probability of yes
    P(no)= probability of no

# %% [markdown]
# ![image.png](attachment:76502d61-be39-425a-8363-08bc13390177.png)

# %% [markdown]
# ![image.png](attachment:d27a3420-6872-4abb-9073-7385a4bc1d61.png)

# %% [markdown]
# ![image.png](attachment:2405fbdc-4590-42bf-9dc7-6d9765e8da58.png)
